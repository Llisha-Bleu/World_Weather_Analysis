# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1       
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                              "Country": city_country,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 2 of Set 1 | faanui
# Processing Record 3 of Set 1 | richards bay
# Processing Record 4 of Set 1 | pop
# Processing Record 5 of Set 1 | castro
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | carnarvon
# Processing Record 9 of Set 1 | joshimath
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | severo-kurilsk
# Processing Record 12 of Set 1 | palmer
# Processing Record 13 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 1 | wa
# City not found. Skipping...
# Processing Record 15 of Set 1 | husavik
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | praia
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | ilulissat
# Processing Record 21 of Set 1 | vaitape
# Processing Record 22 of Set 1 | codrington
# Processing Record 23 of Set 1 | kuusamo
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | dembi dolo
# Processing Record 27 of Set 1 | yellowknife
# Processing Record 28 of Set 1 | ibra
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | new norfolk
# Processing Record 31 of Set 1 | tazovskiy
# Processing Record 32 of Set 1 | churapcha
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | arroyo
# Processing Record 35 of Set 1 | souillac
# Processing Record 36 of Set 1 | fairbanks
# Processing Record 37 of Set 1 | bukama
# Processing Record 38 of Set 1 | kichera
# Processing Record 39 of Set 1 | provideniya
# Processing Record 40 of Set 1 | tasiilaq
# Processing Record 41 of Set 1 | kano
# Processing Record 42 of Set 1 | tukrah
# Processing Record 43 of Set 1 | turayf
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | kristiinankaupunki
# Processing Record 47 of Set 1 | lisakovsk
# Processing Record 48 of Set 1 | la palma
# Processing Record 49 of Set 1 | praia da vitoria
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | saint-philippe
# Processing Record 2 of Set 2 | oksovskiy
# Processing Record 3 of Set 2 | lebu
# Processing Record 4 of Set 2 | inuvik
# Processing Record 5 of Set 2 | hami
# Processing Record 6 of Set 2 | bredasdorp
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | dalbandin
# Processing Record 9 of Set 2 | mar del plata
# Processing Record 10 of Set 2 | nome
# Processing Record 11 of Set 2 | tyukhtet
# Processing Record 12 of Set 2 | katsuura
# Processing Record 13 of Set 2 | kabanjahe
# Processing Record 14 of Set 2 | bathsheba
# Processing Record 15 of Set 2 | weiser
# Processing Record 16 of Set 2 | amapa
# Processing Record 17 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 2 | odienne
# Processing Record 19 of Set 2 | bluff
# Processing Record 20 of Set 2 | kodiak
# Processing Record 21 of Set 2 | arraial do cabo
# Processing Record 22 of Set 2 | vila velha
# Processing Record 23 of Set 2 | avarua
# Processing Record 24 of Set 2 | puerto del rosario
# Processing Record 25 of Set 2 | lavrentiya
# Processing Record 26 of Set 2 | nanortalik
# Processing Record 27 of Set 2 | binzhou
# Processing Record 28 of Set 2 | ca mau
# Processing Record 29 of Set 2 | bengkulu
# Processing Record 30 of Set 2 | talkha
# Processing Record 31 of Set 2 | victoria
# Processing Record 32 of Set 2 | bengkalis
# City not found. Skipping...
# Processing Record 33 of Set 2 | kulhudhuffushi
# Processing Record 34 of Set 2 | barrow
# Processing Record 35 of Set 2 | alta floresta
# Processing Record 36 of Set 2 | chuy
# Processing Record 37 of Set 2 | ulaangom
# Processing Record 38 of Set 2 | maningrida
# Processing Record 39 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 2 | pangnirtung
# Processing Record 41 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 42 of Set 2 | valdivia
# Processing Record 43 of Set 2 | wanning
# Processing Record 44 of Set 2 | dikson
# Processing Record 45 of Set 2 | fortuna
# Processing Record 46 of Set 2 | nebug
# Processing Record 47 of Set 2 | norman wells
# Processing Record 48 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 2 | cherskiy
# Processing Record 50 of Set 2 | saskylakh
# Processing Record 1 of Set 3 | honningsvag
# Processing Record 2 of Set 3 | butembo
# Processing Record 3 of Set 3 | vanimo
# Processing Record 4 of Set 3 | cairns
# Processing Record 5 of Set 3 | kavieng
# Processing Record 6 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 3 | hithadhoo
# Processing Record 8 of Set 3 | lata
# Processing Record 9 of Set 3 | pevek
# Processing Record 10 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 3 | lompoc
# Processing Record 12 of Set 3 | chokurdakh
# Processing Record 13 of Set 3 | touros
# Processing Record 14 of Set 3 | kawalu
# Processing Record 15 of Set 3 | kaitangata
# Processing Record 16 of Set 3 | puerto ayora
# Processing Record 17 of Set 3 | butaritari
# Processing Record 18 of Set 3 | east london
# Processing Record 19 of Set 3 | beringovskiy
# Processing Record 20 of Set 3 | georgetown
# Processing Record 21 of Set 3 | sabratah
# Processing Record 22 of Set 3 | henties bay
# Processing Record 23 of Set 3 | atuona
# Processing Record 24 of Set 3 | yerbogachen
# Processing Record 25 of Set 3 | monteagudo
# Processing Record 26 of Set 3 | lindi
# Processing Record 27 of Set 3 | shelburne
# Processing Record 28 of Set 3 | hualmay
# Processing Record 29 of Set 3 | samarai
# Processing Record 30 of Set 3 | cabo san lucas
# Processing Record 31 of Set 3 | kargasok
# Processing Record 32 of Set 3 | saldanha
# Processing Record 33 of Set 3 | geraldton
# Processing Record 34 of Set 3 | pisco
# Processing Record 35 of Set 3 | laerdalsoyri
# Processing Record 36 of Set 3 | yar-sale
# Processing Record 37 of Set 3 | praya
# Processing Record 38 of Set 3 | kununurra
# Processing Record 39 of Set 3 | ha tinh
# Processing Record 40 of Set 3 | camp verde
# Processing Record 41 of Set 3 | itarema
# Processing Record 42 of Set 3 | hilo
# Processing Record 43 of Set 3 | lakes entrance
# Processing Record 44 of Set 3 | ketovo
# Processing Record 45 of Set 3 | carutapera
# Processing Record 46 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 3 | camanci
# City not found. Skipping...
# Processing Record 48 of Set 3 | williamsport
# Processing Record 49 of Set 3 | mareeba
# Processing Record 50 of Set 3 | bonthe
# Processing Record 1 of Set 4 | nikolskoye
# Processing Record 2 of Set 4 | jiangyou
# Processing Record 3 of Set 4 | katherine
# Processing Record 4 of Set 4 | bac lieu
# Processing Record 5 of Set 4 | sabla
# Processing Record 6 of Set 4 | pineville
# Processing Record 7 of Set 4 | banda aceh
# Processing Record 8 of Set 4 | bulancak
# Processing Record 9 of Set 4 | akhtubinsk
# Processing Record 10 of Set 4 | tual
# Processing Record 11 of Set 4 | syracuse
# Processing Record 12 of Set 4 | thompson
# Processing Record 13 of Set 4 | narsaq
# Processing Record 14 of Set 4 | kutum
# Processing Record 15 of Set 4 | valparaiso
# Processing Record 16 of Set 4 | komsomolskiy
# Processing Record 17 of Set 4 | port elizabeth
# Processing Record 18 of Set 4 | estelle
# Processing Record 19 of Set 4 | novobirilyussy
# Processing Record 20 of Set 4 | tuktoyaktuk
# Processing Record 21 of Set 4 | pecos
# Processing Record 22 of Set 4 | tabou
# Processing Record 23 of Set 4 | tahara
# Processing Record 24 of Set 4 | sturgeon bay
# Processing Record 25 of Set 4 | ekhabi
# Processing Record 26 of Set 4 | leningradskiy
# Processing Record 27 of Set 4 | nata
# Processing Record 28 of Set 4 | moyale
# Processing Record 29 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 4 | bethel
# Processing Record 31 of Set 4 | tiksi
# Processing Record 32 of Set 4 | bud
# Processing Record 33 of Set 4 | talnakh
# Processing Record 34 of Set 4 | windhoek
# Processing Record 35 of Set 4 | khatanga
# Processing Record 36 of Set 4 | chandur bazar
# Processing Record 37 of Set 4 | udachnyy
# Processing Record 38 of Set 4 | el badari
# City not found. Skipping...
# Processing Record 39 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 4 | paamiut
# Processing Record 41 of Set 4 | bambous virieux
# Processing Record 42 of Set 4 | severo-yeniseyskiy
# Processing Record 43 of Set 4 | tres palos
# Processing Record 44 of Set 4 | luderitz
# Processing Record 45 of Set 4 | rabo de peixe
# Processing Record 46 of Set 4 | esil
# Processing Record 47 of Set 4 | kloulklubed
# Processing Record 48 of Set 4 | auki
# Processing Record 49 of Set 4 | linjiang
# Processing Record 50 of Set 4 | vardo
# Processing Record 1 of Set 5 | mbekenyera
# Processing Record 2 of Set 5 | buchanan
# Processing Record 3 of Set 5 | lagoa
# Processing Record 4 of Set 5 | ribeira grande
# Processing Record 5 of Set 5 | college
# Processing Record 6 of Set 5 | san patricio
# Processing Record 7 of Set 5 | cam pha
# City not found. Skipping...
# Processing Record 8 of Set 5 | esperance
# Processing Record 9 of Set 5 | alofi
# Processing Record 10 of Set 5 | longyearbyen
# Processing Record 11 of Set 5 | yulara
# Processing Record 12 of Set 5 | jalu
# Processing Record 13 of Set 5 | christchurch
# Processing Record 14 of Set 5 | vidim
# Processing Record 15 of Set 5 | chapais
# Processing Record 16 of Set 5 | hue
# Processing Record 17 of Set 5 | saint-pierre
# Processing Record 18 of Set 5 | banmo
# City not found. Skipping...
# Processing Record 19 of Set 5 | muriwai beach
# Processing Record 20 of Set 5 | mahebourg
# Processing Record 21 of Set 5 | slave lake
# Processing Record 22 of Set 5 | hay river
# Processing Record 23 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 5 | velasco ibarra
# Processing Record 25 of Set 5 | kruisfontein
# Processing Record 26 of Set 5 | ubinskoye
# Processing Record 27 of Set 5 | cabedelo
# Processing Record 28 of Set 5 | westport
# Processing Record 29 of Set 5 | markova
# Processing Record 30 of Set 5 | ngunguru
# Processing Record 31 of Set 5 | kamaishi
# Processing Record 32 of Set 5 | ponta do sol
# Processing Record 33 of Set 5 | tuatapere
# Processing Record 34 of Set 5 | padang
# Processing Record 35 of Set 5 | takoradi
# Processing Record 36 of Set 5 | hokitika
# Processing Record 37 of Set 5 | nelson bay
# Processing Record 38 of Set 5 | jalapa
# Processing Record 39 of Set 5 | beloha
# Processing Record 40 of Set 5 | kushiro
# Processing Record 41 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 5 | acapulco
# Processing Record 43 of Set 5 | jumla
# Processing Record 44 of Set 5 | jurmala
# Processing Record 45 of Set 5 | alegrete
# Processing Record 46 of Set 5 | ballina
# Processing Record 47 of Set 5 | narrabri
# Processing Record 48 of Set 5 | zyryanka
# Processing Record 49 of Set 5 | sherbakul
# Processing Record 50 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 6 | korla
# Processing Record 2 of Set 6 | katha
# City not found. Skipping...
# Processing Record 3 of Set 6 | wattegama
# Processing Record 4 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 6 | dingle
# Processing Record 6 of Set 6 | fort nelson
# Processing Record 7 of Set 6 | osakarovka
# Processing Record 8 of Set 6 | oranjemund
# Processing Record 9 of Set 6 | piacabucu
# Processing Record 10 of Set 6 | yala
# Processing Record 11 of Set 6 | hovd
# Processing Record 12 of Set 6 | pacific grove
# Processing Record 13 of Set 6 | turukhansk
# Processing Record 14 of Set 6 | mecca
# Processing Record 15 of Set 6 | channel-port aux basques
# Processing Record 16 of Set 6 | codajas
# Processing Record 17 of Set 6 | haikou
# Processing Record 18 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 19 of Set 6 | ugoofaaru
# Processing Record 20 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 21 of Set 6 | hoa binh
# Processing Record 22 of Set 6 | minab
# Processing Record 23 of Set 6 | upernavik
# Processing Record 24 of Set 6 | ullapool
# Processing Record 25 of Set 6 | san rafael
# Processing Record 26 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 6 | pozo colorado
# Processing Record 28 of Set 6 | berlevag
# Processing Record 29 of Set 6 | neiafu
# Processing Record 30 of Set 6 | te anau
# Processing Record 31 of Set 6 | esso
# Processing Record 32 of Set 6 | batemans bay
# Processing Record 33 of Set 6 | rawson
# Processing Record 34 of Set 6 | boueni
# Processing Record 35 of Set 6 | opuwo
# Processing Record 36 of Set 6 | kidal
# Processing Record 37 of Set 6 | cananeia
# Processing Record 38 of Set 6 | onguday
# Processing Record 39 of Set 6 | qaanaaq
# Processing Record 40 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 6 | rochelle
# Processing Record 42 of Set 6 | coos bay
# Processing Record 43 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 6 | loa janan
# Processing Record 46 of Set 6 | winona
# Processing Record 47 of Set 6 | karratha
# Processing Record 48 of Set 6 | bundaberg
# Processing Record 49 of Set 6 | okhotsk
# Processing Record 50 of Set 6 | chumphon
# Processing Record 1 of Set 7 | the pas
# Processing Record 2 of Set 7 | bubaque
# Processing Record 3 of Set 7 | ukiah
# Processing Record 4 of Set 7 | mackenzie
# Processing Record 5 of Set 7 | tezu
# Processing Record 6 of Set 7 | kavali
# Processing Record 7 of Set 7 | freeport
# Processing Record 8 of Set 7 | turulung
# Processing Record 9 of Set 7 | koumac
# Processing Record 10 of Set 7 | cidreira
# Processing Record 11 of Set 7 | nikolayevskaya
# Processing Record 12 of Set 7 | outlook
# Processing Record 13 of Set 7 | alpena
# Processing Record 14 of Set 7 | abu samrah
# Processing Record 15 of Set 7 | hayden
# Processing Record 16 of Set 7 | brigantine
# Processing Record 17 of Set 7 | mokrousovo
# Processing Record 18 of Set 7 | haines junction
# Processing Record 19 of Set 7 | terre haute
# Processing Record 20 of Set 7 | jiaojiang
# Processing Record 21 of Set 7 | bissau
# Processing Record 22 of Set 7 | port lincoln
# Processing Record 23 of Set 7 | sibut
# Processing Record 24 of Set 7 | vestmannaeyjar
# Processing Record 25 of Set 7 | basco
# Processing Record 26 of Set 7 | sao filipe
# Processing Record 27 of Set 7 | katangli
# Processing Record 28 of Set 7 | aljezur
# Processing Record 29 of Set 7 | sibu
# Processing Record 30 of Set 7 | mandalgovi
# Processing Record 31 of Set 7 | naron
# Processing Record 32 of Set 7 | sao sebastiao
# Processing Record 33 of Set 7 | canton
# Processing Record 34 of Set 7 | mao
# Processing Record 35 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 36 of Set 7 | dodge city
# Processing Record 37 of Set 7 | dollar
# Processing Record 38 of Set 7 | naushki
# Processing Record 39 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 7 | akyab
# Processing Record 41 of Set 7 | senanga
# Processing Record 42 of Set 7 | la ronge
# Processing Record 43 of Set 7 | malakal
# Processing Record 44 of Set 7 | vila franca do campo
# Processing Record 45 of Set 7 | micheweni
# Processing Record 46 of Set 7 | labuhan
# Processing Record 47 of Set 7 | constitucion
# Processing Record 48 of Set 7 | plettenberg bay
# Processing Record 49 of Set 7 | necochea
# Processing Record 50 of Set 7 | benjamin constant
# Processing Record 1 of Set 8 | clyde river
# Processing Record 2 of Set 8 | straumen
# Processing Record 3 of Set 8 | agadir
# Processing Record 4 of Set 8 | miranda
# Processing Record 5 of Set 8 | araceli
# Processing Record 6 of Set 8 | makakilo city
# Processing Record 7 of Set 8 | ganzhou
# Processing Record 8 of Set 8 | kiama
# Processing Record 9 of Set 8 | liniere
# City not found. Skipping...
# Processing Record 10 of Set 8 | ahipara
# Processing Record 11 of Set 8 | honiara
# Processing Record 12 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 8 | kavaratti
# Processing Record 14 of Set 8 | correntina
# Processing Record 15 of Set 8 | sompeta
# Processing Record 16 of Set 8 | corinto
# Processing Record 17 of Set 8 | kwinana
# Processing Record 18 of Set 8 | madawaska
# Processing Record 19 of Set 8 | vila
# Processing Record 20 of Set 8 | mahadday weyne
# City not found. Skipping...
# Processing Record 21 of Set 8 | wagga wagga
# Processing Record 22 of Set 8 | ayer itam
# City not found. Skipping...
# Processing Record 23 of Set 8 | garissa
# Processing Record 24 of Set 8 | arlit
# Processing Record 25 of Set 8 | isangel
# Processing Record 26 of Set 8 | boden
# Processing Record 27 of Set 8 | along
# Processing Record 28 of Set 8 | sabang
# Processing Record 29 of Set 8 | naryan-mar
# Processing Record 30 of Set 8 | gazli
# Processing Record 31 of Set 8 | abdanan
# Processing Record 32 of Set 8 | airai
# Processing Record 33 of Set 8 | dombas
# Processing Record 34 of Set 8 | nadym
# Processing Record 35 of Set 8 | palu
# Processing Record 36 of Set 8 | iqaluit
# Processing Record 37 of Set 8 | weligama
# Processing Record 38 of Set 8 | hambantota
# Processing Record 39 of Set 8 | west lafayette
# Processing Record 40 of Set 8 | brawley
# Processing Record 41 of Set 8 | sakakah
# Processing Record 42 of Set 8 | mutis
# Processing Record 43 of Set 8 | palic
# Processing Record 44 of Set 8 | domoni
# Processing Record 45 of Set 8 | dalvik
# Processing Record 46 of Set 8 | new bern
# Processing Record 47 of Set 8 | okha
# Processing Record 48 of Set 8 | kingsport
# Processing Record 49 of Set 8 | sao joao da barra
# Processing Record 50 of Set 8 | celestun
# Processing Record 1 of Set 9 | pundaguitan
# Processing Record 2 of Set 9 | lastoursville
# Processing Record 3 of Set 9 | ancud
# Processing Record 4 of Set 9 | luzhou
# Processing Record 5 of Set 9 | ixtapa
# Processing Record 6 of Set 9 | luganville
# Processing Record 7 of Set 9 | kuytun
# Processing Record 8 of Set 9 | newport
# Processing Record 9 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 9 | key biscayne
# Processing Record 11 of Set 9 | shakawe
# Processing Record 12 of Set 9 | rostaq
# City not found. Skipping...
# Processing Record 13 of Set 9 | trapani
# Processing Record 14 of Set 9 | namibe
# Processing Record 15 of Set 9 | pampierstad
# Processing Record 16 of Set 9 | torbay
# Processing Record 17 of Set 9 | saint-joseph
# Processing Record 18 of Set 9 | ulaanbaatar
# Processing Record 19 of Set 9 | remontnoye
# Processing Record 20 of Set 9 | san juan
# Processing Record 21 of Set 9 | antofagasta
# Processing Record 22 of Set 9 | namatanai
# Processing Record 23 of Set 9 | benjamin aceval
# Processing Record 24 of Set 9 | pringsewu
# Processing Record 25 of Set 9 | shingu
# Processing Record 26 of Set 9 | champerico
# Processing Record 27 of Set 9 | san quintin
# Processing Record 28 of Set 9 | vuktyl
# Processing Record 29 of Set 9 | palaikastron
# Processing Record 30 of Set 9 | tigil
# Processing Record 31 of Set 9 | berdigestyakh
# Processing Record 32 of Set 9 | nantucket
# Processing Record 33 of Set 9 | margate
# Processing Record 34 of Set 9 | severodvinsk
# Processing Record 35 of Set 9 | hirara
# Processing Record 36 of Set 9 | saint-augustin
# Processing Record 37 of Set 9 | atar
# Processing Record 38 of Set 9 | yankton
# Processing Record 39 of Set 9 | surt
# Processing Record 40 of Set 9 | port keats
# Processing Record 41 of Set 9 | kahului
# Processing Record 42 of Set 9 | port hardy
# Processing Record 43 of Set 9 | pathein
# Processing Record 44 of Set 9 | vincennes
# Processing Record 45 of Set 9 | rutana
# Processing Record 46 of Set 9 | parrita
# Processing Record 47 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 9 | port-gentil
# Processing Record 49 of Set 9 | yingzhong
# City not found. Skipping...
# Processing Record 50 of Set 9 | kieta
# Processing Record 1 of Set 10 | huarmey
# Processing Record 2 of Set 10 | karpathos
# Processing Record 3 of Set 10 | banjar
# Processing Record 4 of Set 10 | siderno
# Processing Record 5 of Set 10 | skiros
# City not found. Skipping...
# Processing Record 6 of Set 10 | dawlatabad
# Processing Record 7 of Set 10 | alice springs
# Processing Record 8 of Set 10 | smithers
# Processing Record 9 of Set 10 | west plains
# Processing Record 10 of Set 10 | moron
# Processing Record 11 of Set 10 | copiapo
# Processing Record 12 of Set 10 | singkang
# Processing Record 13 of Set 10 | nueve de julio
# Processing Record 14 of Set 10 | grand gaube
# Processing Record 15 of Set 10 | sinnamary
# Processing Record 16 of Set 10 | manta
# Processing Record 17 of Set 10 | suntar
# Processing Record 18 of Set 10 | havelock
# Processing Record 19 of Set 10 | kemijarvi
# Processing Record 20 of Set 10 | vao
# Processing Record 21 of Set 10 | xichang
# Processing Record 22 of Set 10 | pindushi
# Processing Record 23 of Set 10 | byron bay
# Processing Record 24 of Set 10 | zhezkazgan
# Processing Record 25 of Set 10 | goderich
# Processing Record 26 of Set 10 | wajid
# Processing Record 27 of Set 10 | bowen
# Processing Record 28 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 10 | gainesville
# Processing Record 30 of Set 10 | riyadh
# Processing Record 31 of Set 10 | kulunda
# Processing Record 32 of Set 10 | port said
# Processing Record 33 of Set 10 | sur
# Processing Record 34 of Set 10 | umba
# Processing Record 35 of Set 10 | cascais
# Processing Record 36 of Set 10 | yelizovo
# Processing Record 37 of Set 10 | hangu
# Processing Record 38 of Set 10 | lorengau
# Processing Record 39 of Set 10 | najran
# Processing Record 40 of Set 10 | bentiu
# Processing Record 41 of Set 10 | maues
# Processing Record 42 of Set 10 | porto murtinho
# Processing Record 43 of Set 10 | waycross
# Processing Record 44 of Set 10 | wuchi
# Processing Record 45 of Set 10 | viedma
# Processing Record 46 of Set 10 | dunedin
# Processing Record 47 of Set 10 | panzhihua
# Processing Record 48 of Set 10 | kupang
# Processing Record 49 of Set 10 | olafsvik
# Processing Record 50 of Set 10 | pochutla
# Processing Record 1 of Set 11 | eureka
# Processing Record 2 of Set 11 | kofele
# Processing Record 3 of Set 11 | lencois paulista
# Processing Record 4 of Set 11 | sept-iles
# Processing Record 5 of Set 11 | salinas
# Processing Record 6 of Set 11 | ivanteyevka
# Processing Record 7 of Set 11 | alugan
# Processing Record 8 of Set 11 | cartagena
# Processing Record 9 of Set 11 | talaya
# Processing Record 10 of Set 11 | pedasi
# Processing Record 11 of Set 11 | laborie
# Processing Record 12 of Set 11 | marsa matruh
# Processing Record 13 of Set 11 | burley
# Processing Record 14 of Set 11 | kilindoni
# Processing Record 15 of Set 11 | kyren
# Processing Record 16 of Set 11 | faya
# Processing Record 17 of Set 11 | maputo
# Processing Record 18 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 19 of Set 11 | talcahuano
# Processing Record 20 of Set 11 | port hedland
# Processing Record 21 of Set 11 | zhigalovo
# Processing Record 22 of Set 11 | itamaraca
# Processing Record 23 of Set 11 | nuuk
# Processing Record 24 of Set 11 | herat
# Processing Record 25 of Set 11 | corner brook
# Processing Record 26 of Set 11 | high level
# Processing Record 27 of Set 11 | hasaki
# Processing Record 28 of Set 11 | antalya
# Processing Record 29 of Set 11 | cerro largo
# Processing Record 30 of Set 11 | deulgaon raja
# Processing Record 31 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 32 of Set 11 | jalingo
# Processing Record 33 of Set 11 | santana do livramento
# Processing Record 34 of Set 11 | emba
# Processing Record 35 of Set 11 | asau
# Processing Record 36 of Set 11 | svetlaya
# Processing Record 37 of Set 11 | manokwari
# Processing Record 38 of Set 11 | krasnovishersk
# Processing Record 39 of Set 11 | kysyl-syr
# Processing Record 40 of Set 11 | santiago del estero
# Processing Record 41 of Set 11 | goundam
# Processing Record 42 of Set 11 | bhadrachalam
# Processing Record 43 of Set 11 | kaeo
# Processing Record 44 of Set 11 | santa rosa
# Processing Record 45 of Set 11 | la chapelle-sur-erdre
# Processing Record 46 of Set 11 | guerrero negro
# Processing Record 47 of Set 11 | shepetivka
# Processing Record 48 of Set 11 | mabaruma
# Processing Record 49 of Set 11 | bonavista
# Processing Record 50 of Set 11 | ferrandina
# Processing Record 1 of Set 12 | grindavik
# Processing Record 2 of Set 12 | moerai
# Processing Record 3 of Set 12 | miyako
# Processing Record 4 of Set 12 | rocha
# Processing Record 5 of Set 12 | staffanstorp
# Processing Record 6 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 12 | saint-francois
# Processing Record 8 of Set 12 | camacha
# Processing Record 9 of Set 12 | tupelo
# Processing Record 10 of Set 12 | belyy yar
# Processing Record 11 of Set 12 | kikwit
# Processing Record 12 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 12 | pachino
# Processing Record 14 of Set 12 | nouadhibou
# Processing Record 15 of Set 12 | tatawin
# Processing Record 16 of Set 12 | thabazimbi
# Processing Record 17 of Set 12 | khandyga
# Processing Record 18 of Set 12 | petrozavodsk
# Processing Record 19 of Set 12 | palauig
# Processing Record 20 of Set 12 | pskov
# Processing Record 21 of Set 12 | ewa beach
# Processing Record 22 of Set 12 | gamba
# Processing Record 23 of Set 12 | ottobrunn
# Processing Record 24 of Set 12 | klaksvik
# Processing Record 25 of Set 12 | hervey bay
# Processing Record 26 of Set 12 | allapalli
# Processing Record 27 of Set 12 | axim
# Processing Record 28 of Set 12 | malibu
# Processing Record 29 of Set 12 | pangoa
# Processing Record 30 of Set 12 | bozeman
# Processing Record 31 of Set 12 | gold coast
# Processing Record 32 of Set 12 | doha
# Processing Record 33 of Set 12 | shimoda
# Processing Record 34 of Set 12 | aksehir
# Processing Record 35 of Set 12 | angoche
# Processing Record 36 of Set 12 | lima
# Processing Record 37 of Set 12 | marystown
# Processing Record 38 of Set 12 | omboue
# Processing Record 39 of Set 12 | tommot
# Processing Record 40 of Set 12 | borogontsy
# Processing Record 41 of Set 12 | ondorhaan
# City not found. Skipping...
# Processing Record 42 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 43 of Set 12 | sitka
# Processing Record 44 of Set 12 | mehamn
# Processing Record 45 of Set 12 | buraydah
# Processing Record 46 of Set 12 | flinders
# Processing Record 47 of Set 12 | ostrovnoy
# Processing Record 48 of Set 12 | anloga
# Processing Record 49 of Set 12 | kasempa
# Processing Record 50 of Set 12 | nizhniy odes
# Processing Record 1 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 2 of Set 13 | gweta
# Processing Record 3 of Set 13 | kamenka
# Processing Record 4 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 5 of Set 13 | naze
# Processing Record 6 of Set 13 | changping
# Processing Record 7 of Set 13 | cap malheureux
# Processing Record 8 of Set 13 | gorshechnoye
# Processing Record 9 of Set 13 | jahanabad
# Processing Record 10 of Set 13 | rio gallegos
# Processing Record 11 of Set 13 | truckee
# Processing Record 12 of Set 13 | novyy urengoy
# Processing Record 13 of Set 13 | maravilha
# Processing Record 14 of Set 13 | benoy
# Processing Record 15 of Set 13 | tome-acu
# City not found. Skipping...
# Processing Record 16 of Set 13 | igrim
# Processing Record 17 of Set 13 | marawi
# Processing Record 18 of Set 13 | adrar
# Processing Record 19 of Set 13 | beira
# Processing Record 20 of Set 13 | yuzhnyy
# Processing Record 21 of Set 13 | manzhouli
# Processing Record 22 of Set 13 | puerto suarez
# Processing Record 23 of Set 13 | changji
# Processing Record 24 of Set 13 | meulaboh
# Processing Record 25 of Set 13 | santa cruz del sur
# Processing Record 26 of Set 13 | sao raimundo nonato
# Processing Record 27 of Set 13 | roma
# Processing Record 28 of Set 13 | comodoro rivadavia
# Processing Record 29 of Set 13 | salalah
# Processing Record 30 of Set 13 | milkovo
# Processing Record 31 of Set 13 | lake city
# Processing Record 32 of Set 13 | taguatinga
# Processing Record 33 of Set 13 | inhambane
# Processing Record 34 of Set 13 | zalantun
# Processing Record 35 of Set 13 | sao gabriel da cachoeira
# Processing Record 36 of Set 13 | butka
# Processing Record 37 of Set 13 | abaete
# Processing Record 38 of Set 13 | cobija
# Processing Record 39 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 13 | sungai padi
# Processing Record 41 of Set 13 | ozernovskiy
# Processing Record 42 of Set 13 | flin flon
# Processing Record 43 of Set 13 | petropavlivka
# Processing Record 44 of Set 13 | imeni babushkina
# Processing Record 45 of Set 13 | pucallpa
# Processing Record 46 of Set 13 | whitehorse
# Processing Record 47 of Set 13 | ridgecrest
# Processing Record 48 of Set 13 | khalkhal
# Processing Record 49 of Set 13 | camana
# Processing Record 50 of Set 13 | atherton
# Processing Record 1 of Set 14 | srednekolymsk
# Processing Record 2 of Set 14 | sal rei
# Processing Record 3 of Set 14 | caravelas
# Processing Record 4 of Set 14 | oranjestad
# Processing Record 5 of Set 14 | kampene
# Processing Record 6 of Set 14 | siuna
# Processing Record 7 of Set 14 | pemangkat
# Processing Record 8 of Set 14 | chaibasa
# Processing Record 9 of Set 14 | cagsiay
# Processing Record 10 of Set 14 | coripata
# Processing Record 11 of Set 14 | coihaique
# Processing Record 12 of Set 14 | terra santa
# Processing Record 13 of Set 14 | maceio
# Processing Record 14 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 15 of Set 14 | mikhaylovka
# Processing Record 16 of Set 14 | khandbari
# Processing Record 17 of Set 14 | mount gambier
# Processing Record 18 of Set 14 | santa isabel do rio negro
# Processing Record 19 of Set 14 | humboldt
# Processing Record 20 of Set 14 | hamilton
# Processing Record 21 of Set 14 | verkhnevilyuysk
# Processing Record 22 of Set 14 | mackay
# Processing Record 23 of Set 14 | loukhi
# Processing Record 24 of Set 14 | murgab
# Processing Record 25 of Set 14 | arman
# Processing Record 26 of Set 14 | peachland
# Processing Record 27 of Set 14 | mayo
# Processing Record 28 of Set 14 | moose factory
# Processing Record 29 of Set 14 | uniontown
# Processing Record 30 of Set 14 | san andres
# Processing Record 31 of Set 14 | port blair
# Processing Record 32 of Set 14 | murray bridge
# Processing Record 33 of Set 14 | roald
# Processing Record 34 of Set 14 | sun city west
# Processing Record 35 of Set 14 | inirida
# Processing Record 36 of Set 14 | teguldet
# Processing Record 37 of Set 14 | green river
# Processing Record 38 of Set 14 | chernyshevskiy
# Processing Record 39 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 40 of Set 14 | pontes e lacerda
# Processing Record 41 of Set 14 | trinidad
# Processing Record 42 of Set 14 | emerald
# Processing Record 43 of Set 14 | dicabisagan
# Processing Record 44 of Set 14 | portree
# Processing Record 45 of Set 14 | umm lajj
# Processing Record 46 of Set 14 | miyazu
# Processing Record 47 of Set 14 | mangan
# Processing Record 48 of Set 14 | kitimat
# Processing Record 49 of Set 14 | cumana
# Processing Record 50 of Set 14 | santa maria
# Processing Record 1 of Set 15 | basavana bagevadi
# Processing Record 2 of Set 15 | kitaibaraki
# Processing Record 3 of Set 15 | ladybrand
# Processing Record 4 of Set 15 | balkhash
# Processing Record 5 of Set 15 | barra patuca
# Processing Record 6 of Set 15 | rawah
# Processing Record 7 of Set 15 | limoeiro do ajuru
# Processing Record 8 of Set 15 | aguililla
# Processing Record 9 of Set 15 | tanout
# Processing Record 10 of Set 15 | tessalit
# Processing Record 11 of Set 15 | peno
# Processing Record 12 of Set 15 | walvis bay
# Processing Record 13 of Set 15 | karasburg
# Processing Record 14 of Set 15 | kurilsk
# Processing Record 15 of Set 15 | kenai
# Processing Record 16 of Set 15 | bilma
# Processing Record 17 of Set 15 | lasa
# Processing Record 18 of Set 15 | waingapu
# Processing Record 19 of Set 15 | burtunay
# Processing Record 20 of Set 15 | jutai
# Processing Record 21 of Set 15 | leh
# Processing Record 22 of Set 15 | lubango
# Processing Record 23 of Set 15 | deputatskiy
# Processing Record 24 of Set 15 | diego de almagro
# Processing Record 25 of Set 15 | acarau
# Processing Record 26 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 27 of Set 15 | ola
# Processing Record 28 of Set 15 | ambilobe
# Processing Record 29 of Set 15 | shenjiamen
# Processing Record 30 of Set 15 | tromso
# Processing Record 31 of Set 15 | dayong
# Processing Record 32 of Set 15 | tiznit
# Processing Record 33 of Set 15 | tynda
# Processing Record 34 of Set 15 | ketchikan
# Processing Record 35 of Set 15 | quatre cocos
# Processing Record 36 of Set 15 | kemin
# Processing Record 37 of Set 15 | mon
# Processing Record 38 of Set 15 | doctor arroyo
# Processing Record 39 of Set 15 | shenzhen
# Processing Record 40 of Set 15 | mayuge
# Processing Record 41 of Set 15 | stornoway
# Processing Record 42 of Set 15 | high rock
# Processing Record 43 of Set 15 | stoyba
# City not found. Skipping...
# Processing Record 44 of Set 15 | victoria point
# Processing Record 45 of Set 15 | half moon bay
# Processing Record 46 of Set 15 | taltal
# Processing Record 47 of Set 15 | perth
# Processing Record 48 of Set 15 | sobolevo
# Processing Record 49 of Set 15 | todos santos
# Processing Record 50 of Set 15 | grong
# Processing Record 1 of Set 16 | sao francisco
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Faanui      PF -16.48 -151.75     78.26        82           0
# 1    Richards Bay      ZA -28.78   32.04     59.09        85           0
# 2             Pop      UZ  40.87   71.11     82.40        30           0
# 3          Castro      BR -24.79  -50.01     50.47        95           0
# 4         Rikitea      PF -23.12 -134.97     73.38        80          19
# 5       Busselton      AU -33.65  115.33     57.99        89          43
# 6       Carnarvon      AU -24.87  113.63     66.20        72           0
# 7       Joshimath      IN  30.57   79.57     73.38        53          62
# 8          Hobart      AU -42.88  147.33     57.20        41          75
# 9  Severo-Kurilsk      RU  50.68  156.12     55.24        82          95
#
#    Wind Speed Current Description
# 0       12.93           clear sky
# 1        4.54           clear sky
# 2        6.93           clear sky
# 3        3.38           clear sky
# 4        4.50          few clouds
# 5        1.01          light rain
# 6       16.11           clear sky
# 7        4.59       broken clouds
# 8       19.46       broken clouds
# 9        6.71     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
